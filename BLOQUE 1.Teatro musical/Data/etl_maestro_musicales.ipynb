# %%
import pandas as pd          # Manejo y análisis de datos en tablas (DataFrames)
from IPython.display import display  # Muestra objetos de forma clara en notebooks
import matplotlib.pyplot as plt      # Crear gráficos y visualizaciones
import seaborn as sns        # Gráficos estadísticos atractivos (basado en matplotlib)
from matplotlib.lines import Line2D  # Crear o personalizar líneas en gráficos

# %%
df_listado = pd.read_excel("../Data/musicales_listado.xlsx")
df_listado.head(20)
# Out:
#                             obra   \
# 0                           Annie
# 1                        Avenue Q
# 2                            Hair
# 3                  Los miserables
# 4                         Pegados
# 5                   Forever Young
# 6                          Grease
# 7             Mas de 100 mentiras
# 8                El último jinete
# 9                         Follies
# 10           La bella y la bestia
# 11                   My fair lady
# 12            Sonrisas y lágrimas
# 13                     La llamada
# 14      Marta tiene un marcapasos
# 15                     Sister Act
# 16                 Golfus de Roma
# 17                    El ascensor
# 18                     Flashdance
# 19  Quien mató a Sherlock Holmes?
#
#                                            productora  anio_inicio  anio_fin  \
# 0                                  Theatre Properties         2010      2011
# 1                                              SMedia         2010      2011
# 2   The William Morris Agency Endeavor Entertainme...         2010      2011
# 3                                 Stage Entertainment         2010      2012
# 4                     Ferran González & Alícia Serrat         2010      2013
# 5                                            Tricicle         2011      2022
# 6                                 Drive Entertainment         2011      2014
# 7                                 Drive Entertainment         2011      2013
# 8                       Arabian Horses Production LTD         2012      2013
# 9                                           Mario Gas         2012      2013
# 10                              Stage Entertainment\n         2012      2013
# 11                                Stage Entertainment         2012      2012
# 12                                  ATG Entertainment         2011      2013
# 13                                         Los javies         2013      2024
# 14                                             Smedia         2013      2014
# 15                                Stage Entertainment         2014      2016
# 16                                          Euroscena         2015      2015
# 17                                     Actor’s First.         2017      2018
# 18                                Selladoor Worldwide         2019      2020
# 19                               Beon Entertainment\n         2020      2021
#
#                  teatro ciudad principal  gira  \
# 0          Nuevo Alcalá            Madrid   No
# 1           Nuevo Apolo            Madrid   No
# 2                 Apolo         Barcelona   No
# 3          Lope de Vega            Madrid   Si
# 4        Almería Teatre         Barcelona   Si
# 5          Edp Gran Via            Madrid   Si
# 6            Las Arenas         Barcelona   Si
# 7                Rialto            Madrid   Si
# 8     Teatros del Canal            Madrid   No
# 9               Español            Madrid   No
# 10             Calderón        Valladolid   Si
# 11         Adán Martín           Tenerife   Si
# 12             Coliseum            Madrid   Si
# 13                 Lara            Madrid   Si
# 14         Edp Gran Via            Madrid   Si
# 15               Tívoli         Barcelona   Si
# 16  Veranos de la Villa            Madrid   No
# 17                Pavón            Madrid   Si
# 18               Tívoli         Barcelona   Si
# 19         Edp Gran Via            Madrid   No
#
#                                           fuente_ url activa  duracion
# 0                  https://www.carteleramusicales.es/  False       120
# 1                  https://www.carteleramusicales.es/  False       135
# 2                  https://www.carteleramusicales.es/  False       150
# 3       https://www.stage.es/musicales/los-miserables  False       170
# 4                Pegados (2010) - Cartelera Musicales  False        80
# 5           Forever Young - Compañía Teatral Tricicle  False       100
# 6                 Grease (2011) - Cartelera Musicales  False       150
# 7    Más de 100 mentiras (2011) - Cartelera Musicales  False       170
# 8   https://www.carteleramusicales.es/el-ultimo-ji...  False       130
# 9      https://www.carteleramusicales.es/follies-2012  False       160
# 10  https://www.stage.es/musicales/la-bella-y-la-b...  False       160
# 11        https://www.stage.es/musicales/my-fair-lady  False       165
# 12  https://www.carteleramusicales.es/sonrisas-y-l...  False       150
# 13            La llamada (2013) - Cartelera Musicales  False        95
# 14  Marta tiene un marcapasos (2013) - Cartelera M...  False       160
# 15          https://www.stage.es/musicales/sister-act  False       150
# 16        Golfus de Roma (2015) - Cartelera Musicales  FaLse        90
# 17           El ascensor (2017) - Cartelera Musicales  False        70
# 18            Flashdance (2019) - Cartelera Musicales  False       150
# 19  https://gruposmedia.com/historico/quien-mato-a...  False       105

# %%
df_listado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   obra               33 non-null     object
#  1   productora         33 non-null     object
#  2   anio_inicio        33 non-null     int64
#  3   anio_fin           33 non-null     int64
#  4   teatro             33 non-null     object
#  5   ciudad principal   33 non-null     object
#  6   gira               33 non-null     object
#  7   fuente_ url        33 non-null     object
#  8   activa             33 non-null     object
#  9   duracion           33 non-null     int64
# dtypes: int64(3), object(7)
# memory usage: 2.7+ KB

# %%
# 1. Cargar datasets
df_limpio = pd.read_csv("../Data/musicales_limpio.csv")
df_listado = pd.read_excel("../Data/musicales_listado.xlsx")

# 2. Ver columnas
print(df_limpio.columns)
print(df_listado.columns)
# Out:
# Index(['obra', 'productora', 'anio_inicio', 'anio_fin', 'teatro',
#        'ciudad_principal', 'gira', 'fuente_url', 'activa', 'duracion'],
#       dtype='object')
# Index(['obra ', 'productora', 'anio_inicio', 'anio_fin', 'teatro',
#        'ciudad principal ', 'gira', 'fuente_ url', 'activa', 'duracion'],
#       dtype='object')

# %%
# 1) LIMPIAR NOMBRES DE COLUMNAS (por si hay espacios)
df_limpio.columns  = df_limpio.columns.str.strip()
df_listado.columns = df_listado.columns.str.strip()

# 2) ASEGURAR QUE 'obra' EXISTE (y limpiar texto dentro de las celdas)
#    Esto evita espacios raros dentro del título (no solo en el nombre de la columna)
df_limpio["obra"]  = df_limpio["obra"].astype(str).str.strip()
df_listado["obra"] = df_listado["obra"].astype(str).str.strip()

# 3) QUITAR DURACION DE AMBOS ANTES DE CONCATENAR (para que NO venga del CSV)
df_limpio  = df_limpio.drop(columns=["duracion"], errors="ignore")
df_listado = df_listado.drop(columns=["duracion"], errors="ignore")

# 4) CONCATENAR USANDO SOLO COLUMNAS COMUNES (pero DESPUÉS de asegurar 'obra')
columnas_comunes = df_limpio.columns.intersection(df_listado.columns)
df_maestro = pd.concat(
    [df_limpio[columnas_comunes], df_listado[columnas_comunes]],
    ignore_index=True
)

# 5) RECARGAR EXCEL COMPLETO PARA TRAER DURACIONES
df_listado_full = pd.read_excel("../Data/musicales_listado.xlsx")
df_listado_full.columns = df_listado_full.columns.str.strip()

# 6) CREAR CLAVES PARA MERGE (robusto)
df_maestro["obra_key"] = df_maestro["obra"].astype(str).str.strip().str.lower()
df_listado_full["obra"] = df_listado_full["obra"].astype(str).str.strip()
df_listado_full["obra_key"] = df_listado_full["obra"].str.strip().str.lower()

# 7) TRAER DURACION SOLO DEL EXCEL (left join)
#    Resultado: duracion solo para las obras que estén en el Excel; el resto NaN
df_maestro = df_maestro.merge(
    df_listado_full[["obra_key", "duracion"]],
    on="obra_key",
    how="left"
)

# 8) LIMPIEZA FINAL
df_maestro = df_maestro.drop(columns=["obra_key"])

# %%
print(df_limpio.columns)
print(df_listado.columns)
# Out:
# Index(['obra', 'productora', 'anio_inicio', 'anio_fin', 'teatro',
#        'ciudad_principal', 'gira', 'fuente_url', 'activa'],
#       dtype='object')
# Index(['obra', 'productora', 'anio_inicio', 'anio_fin', 'teatro',
#        'ciudad principal', 'gira', 'fuente_ url', 'activa'],
#       dtype='object')

# %%
df_maestro.head(30)
# Out:
#                                  obra  \
# 0            101 Dálmatas, el musical
# 1                             Aladdín
# 2                           Anastasia
# 3                            Avenue Q
# 4                        Billy Elliot
# 5                             Cabaret
# 6                          Cenicienta
# 7   Charlie y la fábrica de chocolate
# 8                             Chicago
# 9                       Dirty Dancing
# 10               El Día de la Marmota
# 11            El Fantasma de la Ópera
# 12                  El Guardaespaldas
# 13          El Jovencito Frankenstein
# 14                          El Médico
# 15                        El Rey León
# 16           El Tiempo entre Costuras
# 17                  Ghost, el musical
# 18                             Grease
# 19                            Houdini
# 20                        Kinky Boots
# 21                        Kinky Boots
# 22                La Alegría que Pasa
# 23                  La Familia Addams
# 24           La Historia Interminable
# 25              La Jaula de las Locas
# 26                         La Llamada
# 27                     Los Miserables
# 28           Los Pilares de la Tierra
# 29                    Los Productores
#
#                                           productora  anio_inicio  anio_fin  \
# 0   Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2023       NaN
# 1                                Stage Entertainment         2023    2025.0
# 2                                Stage Entertainment         2018    2020.0
# 3   Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2024       NaN
# 4                                        SOM Produce         2017    2020.0
# 5                                   Let's Go Company         2025       NaN
# 6                                Stage Entertainment         2025       NaN
# 7                                   Let's Go Company         2021    2022.0
# 8                                        SOM Produce         2023    2025.0
# 9                                   Let's Go Company         2018    2023.0
# 10                                     Nostromo Live         2024    2025.0
# 11                                  Let's Go Company         2023       NaN
# 12                               Stage Entertainment         2017    2018.0
# 13                                  Let's Go Company         2018    2019.0
# 14                                Beon Entertainment         2018    2023.0
# 15                               Stage Entertainment         2011       NaN
# 16                                Beon Entertainment         2021    2024.0
# 17                                  Let's Go Company         2019    2024.0
# 18                                       SOM Produce         2021    2023.0
# 19                                  Let's Go Company         2025       NaN
# 20                                  Let's Go Company         2021    2022.0
# 21                                Theatre Properties         2024    2025.0
# 22                                      Dagoll Dagom         2022    2023.0
# 23                                  Let's Go Company         2017    2018.0
# 24                                Beon Entertainment         2022    2024.0
# 25                                     Nostromo Live         2018    2020.0
# 26                           Suma Latina / Los Javis         2013       NaN
# 27                                       SOM Produce         2025       NaN
# 28                                Beon Entertainment         2024       NaN
# 29                                     Nostromo Live         2023    2024.0
#
#                                 teatro gira activa  duracion
# 0   Gran Teatro CaixaBank Príncipe Pío   No   True       NaN
# 1                      Teatro Coliseum   No  False       NaN
# 2                      Teatro Coliseum   No  False       NaN
# 3   Gran Teatro CaixaBank Príncipe Pío   No   True     135.0
# 4                  Nuevo Teatro Alcalá   Sí  False       NaN
# 5                              Albéniz   No   True       NaN
# 6                             Coliseum   No   True       NaN
# 7            Espacio Ibercaja Delicias   Sí  False       NaN
# 8                         Teatro Apolo   Sí  False       NaN
# 9                  Teatro Nuevo Alcalá   Sí  False       NaN
# 10               Teatro Coliseum (BCN)   No  False     150.0
# 11         UMusic Hotel Teatro Albéniz   Sí   True       NaN
# 12                     Teatro Coliseum   Sí  False       NaN
# 13                     Teatro Gran Vía   No  False       NaN
# 14                  Teatro Nuevo Apolo   Sí  False       NaN
# 15                 Teatro Lope de Vega   No   True       NaN
# 16        Teatro Principal de Zaragoza   Sí  False       NaN
# 17                 Teatro EDP Gran Vía   Sí  False       NaN
# 18                 Nuevo Teatro Alcalá   Sí  False     150.0
# 19                     Teatro Calderón   No   True       NaN
# 20  Espacio Delicias / Teatro Calderón   No  False       NaN
# 21                       Teatro Rialto   Sí  False       NaN
# 22                    Teatre Poliorama   Sí  False       NaN
# 23                     Teatro Calderón   Sí  False       NaN
# 24                     Teatro Calderón   Sí  False       NaN
# 25                       Teatro Tívoli   Sí  False       NaN
# 26                         Teatro Lara   Sí   True      95.0
# 27                Teatro Apolo (prev.)   No   True     170.0
# 28                 Teatro EDP Gran Vía   Sí   True       NaN
# 29                       Teatro Tívoli   Sí  False       NaN

# %%
df_maestro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   obra         77 non-null     object
#  1   productora   77 non-null     object
#  2   anio_inicio  77 non-null     int64
#  3   anio_fin     64 non-null     float64
#  4   teatro       77 non-null     object
#  5   gira         77 non-null     object
#  6   activa       77 non-null     object
#  7   duracion     41 non-null     float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 4.9+ KB

# %%
df_maestro.describe
# Out:
# <bound method NDFrame.describe of                         obra  \
# 0   101 Dálmatas, el musical
# 1                    Aladdín
# 2                  Anastasia
# 3                   Avenue Q
# 4               Billy Elliot
# ..                       ...
# 72            Come from away
# 73      El día de la marmota
# 74                     Gypsy
# 75   Tocando nuestra canción
# 76      La movida,el musical
#
#                                           productora  anio_inicio  anio_fin  \
# 0   Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2023       NaN
# 1                                Stage Entertainment         2023    2025.0
# 2                                Stage Entertainment         2018    2020.0
# 3   Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2024       NaN
# 4                                        SOM Produce         2017    2020.0
# ..                                               ...          ...       ...
# 72                                 The Stage Company         2024    2025.0
# 73                                     Nostromo live         2024    2025.0
# 74                              Teatro del Soho S.L.         2024    2025.0
# 75                            Teatro del Soho S.L.\n         2024    2024.0
# 76                                Theatre Properties         2024    2025.0
#
#                                 teatro gira activa  duracion
# 0   Gran Teatro CaixaBank Príncipe Pío   No   True       NaN
# 1                      Teatro Coliseum   No  False       NaN
# 2                      Teatro Coliseum   No  False       NaN
# 3   Gran Teatro CaixaBank Príncipe Pío   No   True     135.0
# 4                  Nuevo Teatro Alcalá   Sí  False       NaN
# ..                                 ...  ...    ...       ...
# 72                            Marquina   No  False     100.0
# 73                            Coliseum   No  False     150.0
# 74                            Del Soho   No  False     180.0
# 75                            Del Soho   No  False     165.0
# 76                            Coliseum   Si  False     130.0
#
# [77 rows x 8 columns]>

# %%
# 1) Cargar Excel de obras sin duración
df_sin_duracion = pd.read_excel("../Data/obras_sin_duracion.xlsx")

# 2) Normalizar nombres de columnas
df_sin_duracion.columns = df_sin_duracion.columns.str.strip()

# 3) Crear clave de cruce
df_maestro["obra_key"] = df_maestro["obra"].str.strip().str.lower()
df_sin_duracion["obra_key"] = df_sin_duracion["obra"].str.strip().str.lower()

# 4) Merge para traer la nueva duración
df_maestro = df_maestro.merge(
    df_sin_duracion[["obra_key", "duracion"]],
    on="obra_key",
    how="left",
    suffixes=("", "_nueva")
)

# 5) Rellenar SOLO los NaN con la duración nueva
df_maestro["duracion"] = df_maestro["duracion"].fillna(df_maestro["duracion_nueva"])

# 6) Limpieza final
df_maestro = df_maestro.drop(columns=["duracion_nueva", "obra_key"])

# %%
df_maestro[df_maestro["duracion"].notna()].shape
# Out:
# (77, 8)

# %%
df_maestro["duracion"].notna().sum()
df_maestro["duracion"].isna().sum()
# Out:
# np.int64(0)

# %%
df_maestro.shape
# Out:
# (77, 8)

# %%
df_maestro.columns
# Out:
# Index(['obra', 'productora', 'anio_inicio', 'anio_fin', 'teatro', 'gira',
#        'activa', 'duracion'],
#       dtype='object')

# %%
df_maestro.head(30)
# Out:
#                                  obra  \
# 0            101 Dálmatas, el musical
# 1                             Aladdín
# 2                           Anastasia
# 3                            Avenue Q
# 4                        Billy Elliot
# 5                             Cabaret
# 6                          Cenicienta
# 7   Charlie y la fábrica de chocolate
# 8                             Chicago
# 9                       Dirty Dancing
# 10               El Día de la Marmota
# 11            El Fantasma de la Ópera
# 12                  El Guardaespaldas
# 13          El Jovencito Frankenstein
# 14                          El Médico
# 15                        El Rey León
# 16           El Tiempo entre Costuras
# 17                  Ghost, el musical
# 18                             Grease
# 19                            Houdini
# 20                        Kinky Boots
# 21                        Kinky Boots
# 22                La Alegría que Pasa
# 23                  La Familia Addams
# 24           La Historia Interminable
# 25              La Jaula de las Locas
# 26                         La Llamada
# 27                     Los Miserables
# 28           Los Pilares de la Tierra
# 29                    Los Productores
#
#                                           productora  anio_inicio  anio_fin  \
# 0   Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2023       NaN
# 1                                Stage Entertainment         2023    2025.0
# 2                                Stage Entertainment         2018    2020.0
# 3   Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2024       NaN
# 4                                        SOM Produce         2017    2020.0
# 5                                   Let's Go Company         2025       NaN
# 6                                Stage Entertainment         2025       NaN
# 7                                   Let's Go Company         2021    2022.0
# 8                                        SOM Produce         2023    2025.0
# 9                                   Let's Go Company         2018    2023.0
# 10                                     Nostromo Live         2024    2025.0
# 11                                  Let's Go Company         2023       NaN
# 12                               Stage Entertainment         2017    2018.0
# 13                                  Let's Go Company         2018    2019.0
# 14                                Beon Entertainment         2018    2023.0
# 15                               Stage Entertainment         2011       NaN
# 16                                Beon Entertainment         2021    2024.0
# 17                                  Let's Go Company         2019    2024.0
# 18                                       SOM Produce         2021    2023.0
# 19                                  Let's Go Company         2025       NaN
# 20                                  Let's Go Company         2021    2022.0
# 21                                Theatre Properties         2024    2025.0
# 22                                      Dagoll Dagom         2022    2023.0
# 23                                  Let's Go Company         2017    2018.0
# 24                                Beon Entertainment         2022    2024.0
# 25                                     Nostromo Live         2018    2020.0
# 26                           Suma Latina / Los Javis         2013       NaN
# 27                                       SOM Produce         2025       NaN
# 28                                Beon Entertainment         2024       NaN
# 29                                     Nostromo Live         2023    2024.0
#
#                                 teatro gira activa  duracion
# 0   Gran Teatro CaixaBank Príncipe Pío   No   True      90.0
# 1                      Teatro Coliseum   No  False     145.0
# 2                      Teatro Coliseum   No  False      95.0
# 3   Gran Teatro CaixaBank Príncipe Pío   No   True     135.0
# 4                  Nuevo Teatro Alcalá   Sí  False     150.0
# 5                              Albéniz   No   True     150.0
# 6                             Coliseum   No   True     145.0
# 7            Espacio Ibercaja Delicias   Sí  False     150.0
# 8                         Teatro Apolo   Sí  False     140.0
# 9                  Teatro Nuevo Alcalá   Sí  False     145.0
# 10               Teatro Coliseum (BCN)   No  False     150.0
# 11         UMusic Hotel Teatro Albéniz   Sí   True     150.0
# 12                     Teatro Coliseum   Sí  False     150.0
# 13                     Teatro Gran Vía   No  False     135.0
# 14                  Teatro Nuevo Apolo   Sí  False     180.0
# 15                 Teatro Lope de Vega   No   True     165.0
# 16        Teatro Principal de Zaragoza   Sí  False     150.0
# 17                 Teatro EDP Gran Vía   Sí  False     135.0
# 18                 Nuevo Teatro Alcalá   Sí  False     150.0
# 19                     Teatro Calderón   No   True      95.0
# 20  Espacio Delicias / Teatro Calderón   No  False     130.0
# 21                       Teatro Rialto   Sí  False     130.0
# 22                    Teatre Poliorama   Sí  False      90.0
# 23                     Teatro Calderón   Sí  False     140.0
# 24                     Teatro Calderón   Sí  False     160.0
# 25                       Teatro Tívoli   Sí  False     120.0
# 26                         Teatro Lara   Sí   True      95.0
# 27                Teatro Apolo (prev.)   No   True     170.0
# 28                 Teatro EDP Gran Vía   Sí   True     175.0
# 29                       Teatro Tívoli   Sí  False     150.0

# %%
df_maestro.loc[
    df_maestro["obra"] == "Golfus de Roma",
    ["obra", "productora", "anio_inicio", "teatro", "duracion"]
]
# Out:
#               obra                productora  anio_inicio  \
# 58  Golfus de Roma                 Euroscena         2015
# 59  Golfus de Roma                 Euroscena         2015
# 67  Golfus de Roma  Pentación Espectáculos\n         2022
# 68  Golfus de Roma  Pentación Espectáculos\n         2022
#
#                  teatro  duracion
# 58  Veranos de la Villa      90.0
# 59  Veranos de la Villa     155.0
# 67            La latina      90.0
# 68            La latina     155.0

# %%
# ================================
# FIX FINAL: "Golfus de Roma"
# ================================

# 1) Corregir duración 90 -> 95
df_maestro.loc[
    (df_maestro["obra"] == "Golfus de Roma") &
    (df_maestro["duracion"] == 90),
    "duracion"
] = 95

# 2) Quedarse con 1 fila por versión (obra + productora + año)
#    Esto elimina SOLO la duplicada interna de 2015 y la duplicada interna de 2022.
df_maestro = (
    df_maestro
    .sort_values(["obra", "productora", "anio_inicio", "duracion"], ascending=[True, True, True, False])
    .drop_duplicates(subset=["obra", "productora", "anio_inicio"], keep="first")
    .reset_index(drop=True)
)

# 3) Verificación: deben quedar EXACTAMENTE 2 filas
out = df_maestro.loc[
    df_maestro["obra"] == "Golfus de Roma",
    ["obra", "productora", "anio_inicio", "teatro", "duracion"]
].sort_values(["anio_inicio", "productora"])

display(out)
print("Filas 'Golfus de Roma':", out.shape[0])
# Out:
#               obra                productora  anio_inicio  \
# 30  Golfus de Roma                 Euroscena         2015
# 31  Golfus de Roma  Pentación Espectáculos\n         2022
#
#                  teatro  duracion
# 30  Veranos de la Villa     155.0
# 31            La latina     155.0
# Filas 'Golfus de Roma': 2

# %%
df_maestro.loc[
    (df_maestro["obra"] == "Golfus de Roma") &
    (df_maestro["duracion"] == 155),
    "duracion"
] = 93

# %%
df_maestro.loc[
    df_maestro["obra"] == "Golfus de Roma",
    ["obra", "productora", "anio_inicio", "duracion"]
]
# Out:
#               obra                productora  anio_inicio  duracion
# 30  Golfus de Roma                 Euroscena         2015      93.0
# 31  Golfus de Roma  Pentación Espectáculos\n         2022      93.0

# %%
# Normalización segura (no convierte desconocidos en NaN)
map_si_no = {
    "sí": "Sí", "si": "Sí", "s": "Sí", "yes": "Sí", "y": "Sí", "true": "Sí", "1": "Sí",
    "no": "No", "n": "No", "false": "No", "0": "No"
}

for col in ["gira", "activa"]:
    if col in df_maestro.columns:
        df_maestro[col] = (
            df_maestro[col]
            .astype(str)
            .str.strip()
            .str.lower()
            .replace(map_si_no)   # CLAVE: replace, no map
        )
        # Si había NaN reales, los devuelve a NaN (opcional, pero limpio)
        df_maestro.loc[df_maestro[col].isin(["nan", "none", ""]), col] = pd.NA

# %%
df_maestro[["gira","activa"]].value_counts(dropna=False)
# Out:
# gira  activa
# Sí    No        40
# No    No        22
#       Sí         9
# Sí    Sí         4
# Name: count, dtype: int64

# %%
df_maestro["activa"] = (
    df_maestro["activa"]
    .astype(str)
    .str.strip()
    .str.lower()
    .replace({
        "sí": True, "si": True, "s": True, "true": True, "1": True,
        "no": False, "n": False, "false": False, "0": False
    })
)
# Out:
# C:\Users\elaru\AppData\Local\Temp\ipykernel_26288\3097304972.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .replace({

# %%
df_maestro["activa"].dtype
df_maestro["activa"].value_counts(dropna=False)
# Out:
# activa
# False    62
# True     13
# Name: count, dtype: int64

# %%
df_maestro["anio_fin"] = df_maestro["anio_fin"].astype("Int64")
df_maestro["duracion"] = df_maestro["duracion"].astype("Int64")

# %%
df_maestro.head(20)
# Out:
#                                  obra  \
# 0            101 Dálmatas, el musical
# 1                             Aladdín
# 2                           Anastasia
# 3                               Annie
# 4                            Avenue Q
# 5                            Avenue Q
# 6                        Billy Elliot
# 7                             Cabaret
# 8             Cantando bajo la lluvia
# 9                          Cenicienta
# 10  Charlie y la fábrica de chocolate
# 11                            Chicago
# 12                     Come from away
# 13                            Company
# 14                      Dirty Dancing
# 15               El Día de la Marmota
# 16            El Fantasma de la Ópera
# 17                  El Guardaespaldas
# 18          El Jovencito Frankenstein
# 19                          El Médico
#
#                                           productora  anio_inicio  anio_fin  \
# 0   Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2023      <NA>
# 1                                Stage Entertainment         2023      2025
# 2                                Stage Entertainment         2018      2020
# 3                                 Theatre Properties         2010      2011
# 4                                             SMedia         2010      2011
# 5   Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2024      <NA>
# 6                                        SOM Produce         2017      2020
# 7                                   Let's Go Company         2025      <NA>
# 8                                      Nostromo live         2021      2023
# 9                                Stage Entertainment         2025      <NA>
# 10                                  Let's Go Company         2021      2022
# 11                                       SOM Produce         2023      2025
# 12                                 The Stage Company         2024      2025
# 13                            Teatro del Soho S.L.\n         2021      2023
# 14                                  Let's Go Company         2018      2023
# 15                                     Nostromo Live         2024      2025
# 16                                  Let's Go Company         2023      <NA>
# 17                               Stage Entertainment         2017      2018
# 18                                  Let's Go Company         2018      2019
# 19                                Beon Entertainment         2018      2023
#
#                                 teatro gira  activa  duracion
# 0   Gran Teatro CaixaBank Príncipe Pío   No    True        90
# 1                      Teatro Coliseum   No   False       145
# 2                      Teatro Coliseum   No   False        95
# 3                         Nuevo Alcalá   No   False       120
# 4                          Nuevo Apolo   No   False       135
# 5   Gran Teatro CaixaBank Príncipe Pío   No    True       135
# 6                  Nuevo Teatro Alcalá   Sí   False       150
# 7                              Albéniz   No    True       150
# 8                               Tívoli   Sí   False       150
# 9                             Coliseum   No    True       145
# 10           Espacio Ibercaja Delicias   Sí   False       150
# 11                        Teatro Apolo   Sí   False       140
# 12                            Marquina   No   False       100
# 13                            Del Soho   No   False       170
# 14                 Teatro Nuevo Alcalá   Sí   False       145
# 15               Teatro Coliseum (BCN)   No   False       150
# 16         UMusic Hotel Teatro Albéniz   Sí    True       150
# 17                     Teatro Coliseum   Sí   False       150
# 18                     Teatro Gran Vía   No   False       135
# 19                  Teatro Nuevo Apolo   Sí   False       180

# %%
go = pd.read_csv("../Data/musicales_genero_origen.csv", encoding="utf-8")

# limpiar claves
df_maestro["obra"] = df_maestro["obra"].astype(str).str.strip()
go["obra"] = go["obra"].astype(str).str.strip()

# normalizar texto (Title Case)
go["genero"] = go["genero"].astype(str).str.strip().str.title()
go["origen"] = go["origen"].astype(str).str.strip().str.title()

# merge
df_maestro = df_maestro.merge(go[["obra", "genero", "origen"]], on="obra", how="left")

# %%
df_maestro.head(20)
# Out:
#                                  obra  \
# 0            101 Dálmatas, el musical
# 1                             Aladdín
# 2                           Anastasia
# 3                               Annie
# 4                            Avenue Q
# 5                            Avenue Q
# 6                        Billy Elliot
# 7                             Cabaret
# 8             Cantando bajo la lluvia
# 9                          Cenicienta
# 10  Charlie y la fábrica de chocolate
# 11                            Chicago
# 12                     Come from away
# 13                            Company
# 14                      Dirty Dancing
# 15               El Día de la Marmota
# 16            El Fantasma de la Ópera
# 17                  El Guardaespaldas
# 18          El Jovencito Frankenstein
# 19                          El Médico
#
#                                           productora  anio_inicio  anio_fin  \
# 0   Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2023      <NA>
# 1                                Stage Entertainment         2023      2025
# 2                                Stage Entertainment         2018      2020
# 3                                 Theatre Properties         2010      2011
# 4                                             SMedia         2010      2011
# 5   Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2024      <NA>
# 6                                        SOM Produce         2017      2020
# 7                                   Let's Go Company         2025      <NA>
# 8                                      Nostromo live         2021      2023
# 9                                Stage Entertainment         2025      <NA>
# 10                                  Let's Go Company         2021      2022
# 11                                       SOM Produce         2023      2025
# 12                                 The Stage Company         2024      2025
# 13                            Teatro del Soho S.L.\n         2021      2023
# 14                                  Let's Go Company         2018      2023
# 15                                     Nostromo Live         2024      2025
# 16                                  Let's Go Company         2023      <NA>
# 17                               Stage Entertainment         2017      2018
# 18                                  Let's Go Company         2018      2019
# 19                                Beon Entertainment         2018      2023
#
#                                 teatro gira  activa  duracion    genero  \
# 0   Gran Teatro CaixaBank Príncipe Pío   No    True        90   Comedia
# 1                      Teatro Coliseum   No   False       145  Familiar
# 2                      Teatro Coliseum   No   False        95  Familiar
# 3                         Nuevo Alcalá   No   False       120  Familiar
# 4                          Nuevo Apolo   No   False       135   Comedia
# 5   Gran Teatro CaixaBank Príncipe Pío   No    True       135   Comedia
# 6                  Nuevo Teatro Alcalá   Sí   False       150     Drama
# 7                              Albéniz   No    True       150     Drama
# 8                               Tívoli   Sí   False       150   Comedia
# 9                             Coliseum   No    True       145  Familiar
# 10           Espacio Ibercaja Delicias   Sí   False       150  Familiar
# 11                        Teatro Apolo   Sí   False       140   Comedia
# 12                            Marquina   No   False       100     Drama
# 13                            Del Soho   No   False       170   Comedia
# 14                 Teatro Nuevo Alcalá   Sí   False       145     Drama
# 15               Teatro Coliseum (BCN)   No   False       150   Comedia
# 16         UMusic Hotel Teatro Albéniz   Sí    True       150     Drama
# 17                     Teatro Coliseum   Sí   False       150     Drama
# 18                     Teatro Gran Vía   No   False       135   Comedia
# 19                  Teatro Nuevo Apolo   Sí   False       180     Drama
#
#              origen
# 0   Creacion Propia
# 1        Franquicia
# 2        Franquicia
# 3        Franquicia
# 4        Franquicia
# 5        Franquicia
# 6        Franquicia
# 7        Franquicia
# 8        Franquicia
# 9        Franquicia
# 10       Franquicia
# 11       Franquicia
# 12       Franquicia
# 13       Franquicia
# 14       Franquicia
# 15       Franquicia
# 16       Franquicia
# 17       Franquicia
# 18       Franquicia
# 19  Creacion Propia

# %%
df_maestro[df_maestro["genero"].isna() | df_maestro["origen"].isna()][["obra", "genero", "origen"]]
# Out:
#                           obra genero origen
# 23        El día de la marmota    NaN    NaN
# 45                  La llamada    NaN    NaN
# 50              Los miserables    NaN    NaN
# 68  The Full Monty, el musical    NaN    NaN

# %%
obras_validas = go["obra"].unique()
df_maestro = df_maestro[df_maestro["obra"].isin(obras_validas)]

# %%
df_maestro[df_maestro["genero"].isna() | df_maestro["origen"].isna()][["obra", "genero", "origen"]]
# Out:
# Empty DataFrame
# Columns: [obra, genero, origen]
# Index: []

# %%
df_maestro[df_maestro.duplicated(subset="obra", keep=False)][["obra"]].sort_values("obra")
# Out:
#               obra
# 4         Avenue Q
# 5         Avenue Q
# 30  Golfus de Roma
# 31  Golfus de Roma
# 32          Grease
# 33          Grease
# 37     Kinky Boots
# 38     Kinky Boots
# 64      Sister Act
# 65      Sister Act

# %%
obras = [
    "Avenue Q",
    "Golfus de Roma",
    "Kinky Boots",
    "Sister Act",
    "Grease"
]

df_maestro[df_maestro["obra"].isin(obras)][
    ["obra", "productora", "anio_inicio", "anio_fin", "teatro"]
].sort_values(["obra", "anio_inicio"])
# Out:
#               obra                                        productora  \
# 4         Avenue Q                                            SMedia
# 5         Avenue Q  Teatropolis (Gran Teatro CaixaBank Príncipe Pío)
# 30  Golfus de Roma                                         Euroscena
# 31  Golfus de Roma                          Pentación Espectáculos\n
# 32          Grease                               Drive Entertainment
# 33          Grease                                       SOM Produce
# 37     Kinky Boots                                  Let's Go Company
# 38     Kinky Boots                                Theatre Properties
# 64      Sister Act                               Stage Entertainment
# 65      Sister Act                               Stage Entertainment
#
#     anio_inicio  anio_fin                              teatro
# 4          2010      2011                         Nuevo Apolo
# 5          2024      <NA>  Gran Teatro CaixaBank Príncipe Pío
# 30         2015      2015                 Veranos de la Villa
# 31         2022      2023                           La latina
# 32         2011      2014                          Las Arenas
# 33         2021      2023                 Nuevo Teatro Alcalá
# 37         2021      2022  Espacio Delicias / Teatro Calderón
# 38         2024      2025                       Teatro Rialto
# 64         2014      2016                              Tívoli
# 65         2015      2015                 Teatro Nuevo Alcalá

# %%
df_maestro["productora"] = (
    df_maestro["productora"]
    .replace({
        "SOM Produce": "ATG Entertainment",
        "Sun Producer": "ATG Entertainment"
    })
)

# %%
df_maestro["productora"].value_counts()
# Out:
# productora
# Let's Go Company                                                                                                            11
# ATG Entertainment                                                                                                           10
# Stage Entertainment                                                                                                          9
# Theatre Properties                                                                                                           4
# Beon Entertainment                                                                                                           4
# Teatropolis (Gran Teatro CaixaBank Príncipe Pío)                                                                             3
# Nostromo Live                                                                                                                3
# Teatro del Soho S.L.\n                                                                                                       2
# Drive Entertainment                                                                                                          2
# Pentación Espectáculos\n                                                                                                     2
# Dagoll Dagom                                                                                                                 2
# Nostromo live                                                                                                                1
# SMedia                                                                                                                       1
# The Stage Company                                                                                                            1
# Selladoor Worldwide                                                                                                          1
# Arabian Horses Production LTD                                                                                                1
# Actor’s First.                                                                                                               1
# Mario Gas                                                                                                                    1
# Euroscena                                                                                                                    1
# Tricicle                                                                                                                     1
# Teatro del Soho S.L.                                                                                                         1
# The William Morris Agency Endeavor Entertainment; Illuminati Production Group; Publintermedia Consulting; JK Productions     1
# Suma Latina / Los Javis                                                                                                      1
# Stage Entertainment\n                                                                                                        1
# SMedia\n                                                                                                                     1
# Hatchwell Inversiones Musicales S.L.                                                                                         1
# Smedia                                                                                                                       1
# Ferran González & Alícia Serrat                                                                                              1
# Beon Entertainment\n                                                                                                         1
# Theatre Properties\n                                                                                                         1
# Name: count, dtype: int64

# %%
# 9) GUARDAR
df_maestro.to_csv("../Data/maestro_musicales.csv", index=False, encoding="utf-8")
